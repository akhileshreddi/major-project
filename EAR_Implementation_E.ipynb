# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB4
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
print("TensorFlow Version: ", tf.__version__)
# Out:
# TensorFlow Version:  2.7.0

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
IMAGE_SIZE = 128
EPOCHS = 30
BATCH = 8 #increased the batch size to speed up the process to take more samples in each iteration
LR = 1e-4

PATH = "Images/"

# %%
def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "US images/*")))
    masks = sorted(glob(os.path.join(path, "Expert mask images/*")))

    total_size = len(images)
    valid_size = int(split * total_size)
    test_size = int(split * total_size)

    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(PATH)

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
print("Testing data: ", len(test_x))
# Out:
# Training data:  880
# Validation data:  110
# Testing data:  110

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 1.4)

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB4

def attention_gate(input_1, input_2, n_filters):
    g1 = Conv2D(n_filters, kernel_size=1, use_bias=False)(input_1)
    x1 = Conv2D(n_filters, kernel_size=1, use_bias=False)(input_2)
    x2 = Conv2D(n_filters, kernel_size=1, use_bias=False)(input_2)
    psi = Add()([g1, x1])
    psi = Activation('relu')(psi)
    psi = Conv2D(1, kernel_size=1, use_bias=False)(psi)
    psi = Activation('sigmoid')(psi)
    x2 = Multiply()([x2, psi])
    return Add()([x1, x2])

def residual_block(inputs, n_filters):
    x = Conv2D(n_filters, kernel_size=3, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(n_filters, kernel_size=3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Add()([inputs, x])
    return Activation('relu')(x)

def create_model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_model = EfficientNetB4(include_top=False, input_tensor=inputs, weights='imagenet')

    skip_connections = [
        base_model.layers[0].name,    # input layer
        'block2a_expand_activation',  # 64
        'block3a_expand_activation',  # 32
        'block4a_expand_activation',  # 16
        'block6a_expand_activation'   # 8
    ]
    
    encoder_output = base_model.get_layer('block7a_expand_activation').output
    
    f = [256, 64, 32, 16, 8]
    x = encoder_output
    
    for i in range(1, len(skip_connections)+1, 1):
        skip_conn = skip_connections[-i]
        skip_tensor = base_model.get_layer(skip_conn).output
        x = UpSampling2D(size=(2, 2))(x)
        x = attention_gate(x, skip_tensor, f[-i])
        x = residual_block(x, f[-i])
    
    x = Conv2D(1, kernel_size=1, activation='sigmoid')(x)
    
    model = Model(inputs, x)
    
    return model

model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 128, 128, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 129, 129, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 64, 64, 48)   1296        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 64, 64, 48)   192         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 64, 64, 48)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 64, 64, 48)  432         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 64, 64, 48)  192         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 64, 64, 48)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 64, 64, 48)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 64, 64, 24)   1152        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 64, 64, 24)  216         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 64, 64, 24)  96          ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 64, 64, 24)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 64, 64, 24)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 64, 64, 24)   576         ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 64, 64, 24)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 64, 64, 24)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 64, 64, 144)  3456        ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 64, 64, 144)  576        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 64, 64, 144)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 65, 65, 144)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 32, 32, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 32, 32, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 32, 32, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 32, 32, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 32, 32, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 32, 32, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 32, 32, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 32, 32, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 32, 32, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 32, 32, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 32, 32, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 32, 32, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 32, 32, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 32, 32, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 32, 32, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 32, 32, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 32, 32, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 32, 32, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 32, 32, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 32, 32, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 32, 32, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 32, 32, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 32, 32, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 32, 32, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 32, 32, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 32, 32, 192)  6144        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 32, 32, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 32, 32, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 32, 32, 192)  1728       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 32, 32, 192)  768        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 32, 32, 192)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 32, 32, 192)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 32, 32, 32)   6144        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 32, 32, 32)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 32, 32, 32)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 32, 32, 192)  6144        ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 32, 32, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 32, 32, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 35, 35, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 16, 16, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 16, 16, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 16, 16, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 16, 16, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 16, 16, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 16, 16, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 16, 16, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 16, 16, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 16, 16, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 16, 16, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 16, 16, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 16, 16, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 16, 16, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 16, 16, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 16, 16, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 16, 16, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 16, 16, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 16, 16, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 16, 16, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 16, 16, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 16, 16, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 16, 16, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 16, 16, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 16, 16, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 16, 16, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 16, 16, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 16, 16, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 16, 16, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 16, 16, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 16, 16, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 16, 16, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 16, 16, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 16, 16, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 16, 16, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 16, 16, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 16, 16, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 16, 16, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 16, 16, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 16, 16, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 16, 16, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 16, 16, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 16, 16, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 17, 17, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 8, 8, 336)   3024        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 8, 8, 336)   1344        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 8, 8, 336)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 8, 8, 336)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 8, 8, 112)    37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 8, 8, 112)   448         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 8, 8, 672)    75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 8, 8, 672)   2688        ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 8, 8, 672)   0           ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 8, 8, 672)   6048        ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 8, 8, 672)   2688        ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 8, 8, 672)   0           ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 8, 8, 672)    0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 8, 8, 112)    75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 8, 8, 112)   448         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 8, 8, 112)    0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 8, 8, 112)    0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 8, 8, 672)    75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 8, 8, 672)   2688        ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 8, 8, 672)   0           ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 8, 8, 672)   6048        ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 8, 8, 672)   2688        ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 8, 8, 672)   0           ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 672)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4c_se_reduce[0][0]']
# ...
#  multiply_1 (Multiply)          (None, 16, 16, 16)   0           ['conv2d_8[0][0]',
#                                                                   'activation_5[0][0]']
#
#  add_4 (Add)                    (None, 16, 16, 16)   0           ['conv2d_7[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 16)   2304        ['add_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 16)   2304        ['activation_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_11[0][0]']
#  rmalization)
#
#  add_5 (Add)                    (None, 16, 16, 16)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 16)   0           ['add_5[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_7[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 32)   6144        ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 32)   512         ['up_sampling2d_2[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 32)   0           ['conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 32)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 1)    32          ['activation_8[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 32)   6144        ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  activation_9 (Activation)      (None, 32, 32, 1)    0           ['conv2d_15[0][0]']
#
#  multiply_2 (Multiply)          (None, 32, 32, 32)   0           ['conv2d_14[0][0]',
#                                                                   'activation_9[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 32)   0           ['conv2d_13[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 32)   9216        ['add_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 32)   9216        ['activation_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_17[0][0]']
#  rmalization)
#
#  add_8 (Add)                    (None, 32, 32, 32)   0           ['add_7[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 32)   0           ['add_8[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 32)  0           ['activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   9216        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   2048        ['up_sampling2d_3[0][0]']
#
#  add_9 (Add)                    (None, 64, 64, 64)   0           ['conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['add_9[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 1)    64          ['activation_12[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   9216        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  activation_13 (Activation)     (None, 64, 64, 1)    0           ['conv2d_21[0][0]']
#
#  multiply_3 (Multiply)          (None, 64, 64, 64)   0           ['conv2d_20[0][0]',
#                                                                   'activation_13[0][0]']
#
#  add_10 (Add)                   (None, 64, 64, 64)   0           ['conv2d_19[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   36864       ['add_10[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   36864       ['activation_14[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 64, 64, 64)   0           ['add_10[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['add_11[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64  0          ['activation_15[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 25  768         ['input_1[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 25  16384       ['up_sampling2d_4[0][0]']
#                                 6)
#
#  add_12 (Add)                   (None, 128, 128, 25  0           ['conv2d_24[0][0]',
#                                 6)                                'conv2d_25[0][0]']
#
#  activation_16 (Activation)     (None, 128, 128, 25  0           ['add_12[0][0]']
#                                 6)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 1)  256         ['activation_16[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 25  768         ['input_1[0][0]']
#                                 6)
#
#  activation_17 (Activation)     (None, 128, 128, 1)  0           ['conv2d_27[0][0]']
#
#  multiply_4 (Multiply)          (None, 128, 128, 25  0           ['conv2d_26[0][0]',
#                                 6)                                'activation_17[0][0]']
#
#  add_13 (Add)                   (None, 128, 128, 25  0           ['conv2d_25[0][0]',
#                                 6)                                'multiply_4[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 25  589824      ['add_13[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_28[0][0]']
#  rmalization)                   6)
#
#  activation_18 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 25  589824      ['activation_18[0][0]']
#                                 6)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_29[0][0]']
#  rmalization)                   6)
#
#  add_14 (Add)                   (None, 128, 128, 25  0           ['add_13[0][0]',
#                                 6)                                'batch_normalization_9[0][0]']
#
#  activation_19 (Activation)     (None, 128, 128, 25  0           ['add_14[0][0]']
#                                 6)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 1)  257         ['activation_19[0][0]']
#
# ==================================================================================================
# Total params: 14,196,900
# Trainable params: 14,089,581
# Non-trainable params: 107,319
# __________________________________________________________________________________________________

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), Precision()]
model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)

# %%
filepath = 'C:\\Users\\NAGARAJ K\\U-Net'

# %%
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

# %%
callbacks = [
    checkpoint,
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6691 - dice_coef: 0.3309 - recall: 0.6457 - precision: 0.1580
# Epoch 00001: val_loss improved from inf to 0.96221, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 952s 8s/step - loss: 0.6691 - dice_coef: 0.3309 - recall: 0.6457 - precision: 0.1580 - val_loss: 0.9622 - val_dice_coef: 0.0378 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1574 - dice_coef: 0.8426 - recall: 0.9049 - precision: 0.9111
# Epoch 00002: val_loss did not improve from 0.96221
# 110/110 [==============================] - 890s 8s/step - loss: 0.1574 - dice_coef: 0.8426 - recall: 0.9049 - precision: 0.9111 - val_loss: 0.9791 - val_dice_coef: 0.0209 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1435 - dice_coef: 0.8565 - recall: 0.8912 - precision: 0.9006
# Epoch 00003: val_loss did not improve from 0.96221
# 110/110 [==============================] - 835s 8s/step - loss: 0.1435 - dice_coef: 0.8565 - recall: 0.8912 - precision: 0.9006 - val_loss: 0.9865 - val_dice_coef: 0.0135 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0804 - dice_coef: 0.9196 - recall: 0.9347 - precision: 0.9519
# Epoch 00004: val_loss improved from 0.96221 to 0.87944, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 935s 9s/step - loss: 0.0804 - dice_coef: 0.9196 - recall: 0.9347 - precision: 0.9519 - val_loss: 0.8794 - val_dice_coef: 0.1188 - val_recall: 0.0796 - val_precision: 0.9986 - lr: 1.0000e-04
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0644 - dice_coef: 0.9356 - recall: 0.9434 - precision: 0.9590
# Epoch 00005: val_loss improved from 0.87944 to 0.41792, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2221s 20s/step - loss: 0.0644 - dice_coef: 0.9356 - recall: 0.9434 - precision: 0.9590 - val_loss: 0.4179 - val_dice_coef: 0.5808 - val_recall: 0.5123 - val_precision: 0.9806 - lr: 1.0000e-04
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0551 - dice_coef: 0.9449 - recall: 0.9468 - precision: 0.9634
# Epoch 00006: val_loss improved from 0.41792 to 0.18082, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2670s 24s/step - loss: 0.0551 - dice_coef: 0.9449 - recall: 0.9468 - precision: 0.9634 - val_loss: 0.1808 - val_dice_coef: 0.8184 - val_recall: 0.7898 - val_precision: 0.9176 - lr: 1.0000e-04
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0498 - dice_coef: 0.9502 - recall: 0.9496 - precision: 0.9664
# Epoch 00007: val_loss improved from 0.18082 to 0.08453, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2010s 18s/step - loss: 0.0498 - dice_coef: 0.9502 - recall: 0.9496 - precision: 0.9664 - val_loss: 0.0845 - val_dice_coef: 0.9155 - val_recall: 0.9244 - val_precision: 0.9272 - lr: 1.0000e-04
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0471 - dice_coef: 0.9529 - recall: 0.9510 - precision: 0.9674
# Epoch 00008: val_loss did not improve from 0.08453
# 110/110 [==============================] - 2285s 21s/step - loss: 0.0471 - dice_coef: 0.9529 - recall: 0.9510 - precision: 0.9674 - val_loss: 0.6550 - val_dice_coef: 0.3445 - val_recall: 0.6276 - val_precision: 0.2609 - lr: 1.0000e-04
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0435 - dice_coef: 0.9565 - recall: 0.9527 - precision: 0.9701
# Epoch 00009: val_loss did not improve from 0.08453
# 110/110 [==============================] - 2248s 20s/step - loss: 0.0435 - dice_coef: 0.9565 - recall: 0.9527 - precision: 0.9701 - val_loss: 0.1401 - val_dice_coef: 0.8597 - val_recall: 0.9488 - val_precision: 0.8041 - lr: 1.0000e-04
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0427 - dice_coef: 0.9573 - recall: 0.9529 - precision: 0.9711
# Epoch 00010: val_loss did not improve from 0.08453
# 110/110 [==============================] - 2332s 21s/step - loss: 0.0427 - dice_coef: 0.9573 - recall: 0.9529 - precision: 0.9711 - val_loss: 0.2427 - val_dice_coef: 0.7550 - val_recall: 0.6780 - val_precision: 0.8733 - lr: 1.0000e-04
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0402 - dice_coef: 0.9598 - recall: 0.9541 - precision: 0.9730
# Epoch 00011: val_loss did not improve from 0.08453
# 110/110 [==============================] - 2429s 22s/step - loss: 0.0402 - dice_coef: 0.9598 - recall: 0.9541 - precision: 0.9730 - val_loss: 0.1630 - val_dice_coef: 0.8357 - val_recall: 0.7412 - val_precision: 0.9659 - lr: 1.0000e-04
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0372 - dice_coef: 0.9628 - recall: 0.9565 - precision: 0.9752
# Epoch 00012: val_loss improved from 0.08453 to 0.07154, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2480s 23s/step - loss: 0.0372 - dice_coef: 0.9628 - recall: 0.9565 - precision: 0.9752 - val_loss: 0.0715 - val_dice_coef: 0.9288 - val_recall: 0.9117 - val_precision: 0.9522 - lr: 1.0000e-05
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0363 - dice_coef: 0.9637 - recall: 0.9573 - precision: 0.9760
# Epoch 00013: val_loss did not improve from 0.07154
# 110/110 [==============================] - 2807s 25s/step - loss: 0.0363 - dice_coef: 0.9637 - recall: 0.9573 - precision: 0.9760 - val_loss: 0.0745 - val_dice_coef: 0.9260 - val_recall: 0.8803 - val_precision: 0.9755 - lr: 1.0000e-05
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0356 - dice_coef: 0.9644 - recall: 0.9576 - precision: 0.9768
# Epoch 00014: val_loss did not improve from 0.07154
# 110/110 [==============================] - 2720s 25s/step - loss: 0.0356 - dice_coef: 0.9644 - recall: 0.9576 - precision: 0.9768 - val_loss: 0.0775 - val_dice_coef: 0.9231 - val_recall: 0.8675 - val_precision: 0.9819 - lr: 1.0000e-05
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0355 - dice_coef: 0.9645 - recall: 0.9581 - precision: 0.9769
# Epoch 00015: val_loss did not improve from 0.07154
# 110/110 [==============================] - 2637s 24s/step - loss: 0.0355 - dice_coef: 0.9645 - recall: 0.9581 - precision: 0.9769 - val_loss: 0.0722 - val_dice_coef: 0.9283 - val_recall: 0.8811 - val_precision: 0.9788 - lr: 1.0000e-05
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0350 - dice_coef: 0.9650 - recall: 0.9585 - precision: 0.9772
# Epoch 00016: val_loss improved from 0.07154 to 0.07070, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2663s 24s/step - loss: 0.0350 - dice_coef: 0.9650 - recall: 0.9585 - precision: 0.9772 - val_loss: 0.0707 - val_dice_coef: 0.9298 - val_recall: 0.8857 - val_precision: 0.9766 - lr: 1.0000e-05
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0348 - dice_coef: 0.9652 - recall: 0.9582 - precision: 0.9777
# Epoch 00017: val_loss did not improve from 0.07070
# 110/110 [==============================] - 2002s 18s/step - loss: 0.0348 - dice_coef: 0.9652 - recall: 0.9582 - precision: 0.9777 - val_loss: 0.0723 - val_dice_coef: 0.9282 - val_recall: 0.8840 - val_precision: 0.9764 - lr: 1.0000e-05
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0344 - dice_coef: 0.9656 - recall: 0.9588 - precision: 0.9779
# Epoch 00018: val_loss did not improve from 0.07070
# 110/110 [==============================] - 2060s 19s/step - loss: 0.0344 - dice_coef: 0.9656 - recall: 0.9588 - precision: 0.9779 - val_loss: 0.0821 - val_dice_coef: 0.9185 - val_recall: 0.8627 - val_precision: 0.9782 - lr: 1.0000e-05
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0341 - dice_coef: 0.9659 - recall: 0.9587 - precision: 0.9782
# Epoch 00019: val_loss improved from 0.07070 to 0.05996, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2164s 20s/step - loss: 0.0341 - dice_coef: 0.9659 - recall: 0.9587 - precision: 0.9782 - val_loss: 0.0600 - val_dice_coef: 0.9403 - val_recall: 0.9266 - val_precision: 0.9577 - lr: 1.0000e-05
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9661 - recall: 0.9593 - precision: 0.9782
# Epoch 00020: val_loss did not improve from 0.05996
# 110/110 [==============================] - 2035s 18s/step - loss: 0.0339 - dice_coef: 0.9661 - recall: 0.9593 - precision: 0.9782 - val_loss: 0.0624 - val_dice_coef: 0.9379 - val_recall: 0.9189 - val_precision: 0.9605 - lr: 1.0000e-05
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0337 - dice_coef: 0.9663 - recall: 0.9593 - precision: 0.9783
# Epoch 00021: val_loss did not improve from 0.05996
# 110/110 [==============================] - 2020s 18s/step - loss: 0.0337 - dice_coef: 0.9663 - recall: 0.9593 - precision: 0.9783 - val_loss: 0.0762 - val_dice_coef: 0.9243 - val_recall: 0.8858 - val_precision: 0.9670 - lr: 1.0000e-05
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0335 - dice_coef: 0.9665 - recall: 0.9595 - precision: 0.9787
# Epoch 00022: val_loss did not improve from 0.05996
# 110/110 [==============================] - 1870s 17s/step - loss: 0.0335 - dice_coef: 0.9665 - recall: 0.9595 - precision: 0.9787 - val_loss: 0.0633 - val_dice_coef: 0.9370 - val_recall: 0.9196 - val_precision: 0.9578 - lr: 1.0000e-05
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0334 - dice_coef: 0.9666 - recall: 0.9599 - precision: 0.9784
# Epoch 00023: val_loss did not improve from 0.05996
# 110/110 [==============================] - 1922s 17s/step - loss: 0.0334 - dice_coef: 0.9666 - recall: 0.9599 - precision: 0.9784 - val_loss: 0.0611 - val_dice_coef: 0.9392 - val_recall: 0.9264 - val_precision: 0.9557 - lr: 1.0000e-05
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.9672 - recall: 0.9603 - precision: 0.9789
# Epoch 00024: val_loss did not improve from 0.05996
# 110/110 [==============================] - 1853s 17s/step - loss: 0.0328 - dice_coef: 0.9672 - recall: 0.9603 - precision: 0.9789 - val_loss: 0.0604 - val_dice_coef: 0.9399 - val_recall: 0.9249 - val_precision: 0.9576 - lr: 1.0000e-06
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9604 - precision: 0.9792
# Epoch 00025: val_loss improved from 0.05996 to 0.05984, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 1896s 17s/step - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9604 - precision: 0.9792 - val_loss: 0.0598 - val_dice_coef: 0.9405 - val_recall: 0.9265 - val_precision: 0.9578 - lr: 1.0000e-06
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.9671 - recall: 0.9601 - precision: 0.9788
# Epoch 00026: val_loss improved from 0.05984 to 0.05965, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2062s 19s/step - loss: 0.0329 - dice_coef: 0.9671 - recall: 0.9601 - precision: 0.9788 - val_loss: 0.0597 - val_dice_coef: 0.9406 - val_recall: 0.9264 - val_precision: 0.9579 - lr: 1.0000e-06
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0330 - dice_coef: 0.9670 - recall: 0.9597 - precision: 0.9789
# Epoch 00027: val_loss improved from 0.05965 to 0.05963, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 2245s 20s/step - loss: 0.0330 - dice_coef: 0.9670 - recall: 0.9597 - precision: 0.9789 - val_loss: 0.0596 - val_dice_coef: 0.9407 - val_recall: 0.9276 - val_precision: 0.9570 - lr: 1.0000e-06
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9603 - precision: 0.9791
# Epoch 00028: val_loss improved from 0.05963 to 0.05938, saving model to C:\Users\NAGARAJ K\U-Net
# INFO:tensorflow:Assets written to: C:\Users\NAGARAJ K\U-Net\assets
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# E:\Anaconda\envs\Tensor\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# 110/110 [==============================] - 1924s 17s/step - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9603 - precision: 0.9791 - val_loss: 0.0594 - val_dice_coef: 0.9409 - val_recall: 0.9280 - val_precision: 0.9568 - lr: 1.0000e-06
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0325 - dice_coef: 0.9675 - recall: 0.9603 - precision: 0.9793
# Epoch 00029: val_loss did not improve from 0.05938
# 110/110 [==============================] - 1617s 15s/step - loss: 0.0325 - dice_coef: 0.9675 - recall: 0.9603 - precision: 0.9793 - val_loss: 0.0599 - val_dice_coef: 0.9404 - val_recall: 0.9274 - val_precision: 0.9570 - lr: 1.0000e-06
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9605 - precision: 0.9790
# Epoch 00030: val_loss did not improve from 0.05938
# 110/110 [==============================] - 1581s 14s/step - loss: 0.0326 - dice_coef: 0.9674 - recall: 0.9605 - precision: 0.9790 - val_loss: 0.0594 - val_dice_coef: 0.9409 - val_recall: 0.9289 - val_precision: 0.9564 - lr: 1.0000e-06

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1

model.evaluate(test_dataset, steps=test_steps)
# Out:
# 14/14 [==============================] - 65s 5s/step - loss: 0.0467 - dice_coef: 0.9531 - recall: 0.9441 - precision: 0.9663
# [0.046715717762708664,
#  0.9531120657920837,
#  0.9441012144088745,
#  0.9662733674049377]

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:20], test_y[:20])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    a.set_title("____________Original Image________________________Original Mask_________________________Predicted Mask________________")
    a.set_title("..............Original Image............................Original Mask.................................Predicted Mask.................")
    imgplot = plt.imshow(image)
